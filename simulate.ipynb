# %% [markdown]
# Graph fraction of agents conforming to platform's opinion against level of platform bias

# %%
import json

with open('data/platform-vs-polarisation/data-b0-p0.5-c0.1-rec1.json') as f:
	data0 = json.load(f)['data']

with open('data/platform-vs-polarisation/data-b0.5-p0.5-c0.1-rec1.json') as f:
	data1 = json.load(f)['data']

# data0['data']

# %%
def get_data(data):
	xs = []
	ys = []
	for key, val in data.items():
		xs.append(float(key))
		y = []
		for v in val:
			y.append(float(v[1] if v[0] == 1 else v[2]))
		ys.append(sum(y) / len(y))
	return xs, ys

xs0, ys0 = get_data(data0)
xs1, ys1 = get_data(data1)

xs0, ys0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> 		ys.append(sum(y) / len(y))
#      <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> 	return xs, ys
# ---> <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> xs0, ys0 = get_data(data0)
#      <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> xs1, ys1 = get_data(data1)
#      <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> xs0, ys0
#
# /Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb Cell 3 line 8
#       <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> 	y = []
#       <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> 	for v in val:
# ----> <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> 		y.append(float(val[1] if val[0] == 1 else val[2]))
#       <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> 	ys.append(sum(y) / len(y))
#      <a href='vscode-notebook-cell:/Users/jp/Desktop/modelling/project/Social_Media_Simulator/simulate.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> return xs, ys
#
# TypeError: float() argument must be a string or a real number, not 'list'

# %%
import matplotlib.pyplot as plt

plt.plot(xs0, ys0)
# Out:
# [<matplotlib.lines.Line2D at 0x11101cc50>,
#  <matplotlib.lines.Line2D at 0x1110808d0>,
#  <matplotlib.lines.Line2D at 0x111080910>]
